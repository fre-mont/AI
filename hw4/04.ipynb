# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import matplotlib.pyplot as plt 
import numpy as np

# %%
sample = plt.imread("sample.jpg")

# %%
plt.imshow(sample)  # 원본 이미지

# %%
# 증강 이미지 시각화
def aug_image(image):
    image = np.expand_dims(image, axis=0) # 4차원으로 늘려주기
    obj = datagen.flow(image, batch_size=1)
    aug_image = obj.next()
    plt.imshow(aug_image[0])

# %% [markdown]
# ### rotation

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50)

aug_image(sample)

# %% [markdown]
# #### Flip

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,)

aug_image(sample)

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    vertical_flip=True,)

aug_image(sample)

# %% [markdown]
# ### zoom

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=[0.1, 1.5])

aug_image(sample)

# %% [markdown]
# #### brightness

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.01, 2.0])

aug_image(sample)

# %% [markdown]
# ### shift

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.8)

aug_image(sample)

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    height_shift_range=0.9)

aug_image(sample)
